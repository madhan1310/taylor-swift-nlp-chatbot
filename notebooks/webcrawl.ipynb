# %%
from bs4 import BeautifulSoup
import requests
from bs4 import BeautifulSoup
import urllib.request
import re
import os
import numpy as np
import pickle
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.text import ConcordanceIndex
import string

# %%
# Define stop words
stop_words = set(stopwords.words('english'))

# %%
starter_url = "https://en.wikipedia.org/wiki/Taylor_Swift"

r = requests.get(starter_url)
data = r.text
soup = BeautifulSoup(data, 'html.parser')  # Specify the parser explicitly

counter = 0
# write URLs to a file
with open('urls.txt', 'w') as f:
    for link in soup.find_all('a', href=True):  # Find all 'a' tags with 'href' attribute
        url = link.get('href')
        if url.startswith('/wiki/') and ':' not in url:  # Filter out non-article links
            full_url = "https://en.wikipedia.org" + url
            f.write(full_url + '\n')  # Write full URL to file
            counter += 1
            if counter >= 25:
                break

# End of program
print("End of crawler")
# Out:
# End of crawler

# %%
def scrape_text_from_url(url):
    try:
        html = urllib.request.urlopen(url)
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.findAll(text=True)
        result = filter(visible, data)
        temp_list = list(result)
        temp_str = ' '.join(temp_list)
        return temp_str
    except Exception as e:
        print(f"Failed to scrape {url}: {e}")
        return None

# %%
# Function to scrape text from each page and write to files
def scrape_text_and_write_to_files(urls_file, output_dir):
    with open(urls_file, 'r') as f:
        urls = f.readlines()

    for i, url in enumerate(urls):
        url = url.strip()  # Remove leading/trailing whitespaces and newlines
        text = scrape_text_from_url(url)
        if text:
            with open(f"{output_dir}/page_{i}.txt", 'w', encoding='utf-8') as f:
                f.write(text)

# %%
# Function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    # Tokenize the text
    tokens = word_tokenize(text)
    # Remove stopwords
    filtered_tokens = [word for word in tokens if word not in stop_words]
    # Join the tokens back into a string
    cleaned_text = ' '.join(filtered_tokens)
    return cleaned_text

# %%
# Function to clean up text files
def clean_text_files(input_dir, output_dir):
    os.makedirs(output_dir, exist_ok=True)  # Create output directory if it doesn't exist
    for file_name in os.listdir(input_dir):
        if file_name.endswith(".txt"):
            with open(os.path.join(input_dir, file_name), 'r', encoding='utf-8') as f:
                text = f.read()
                cleaned_text = preprocess_text(text)
                with open(os.path.join(output_dir, file_name), 'w', encoding='utf-8') as outfile:
                    outfile.write(cleaned_text)

# %%
# Load scraped text data from files and concatenate
def load_scraped_text(input_dir):
    scraped_text = ""
    for file_name in os.listdir(input_dir):
        if file_name.endswith(".txt"):
            with open(os.path.join(input_dir, file_name), 'r', encoding='utf-8') as f:
                scraped_text += f.read()
    return scraped_text

# %%
# Function to determine if an element is visible
def visible(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return False
    elif re.match('<!--.*-->', str(element.encode('utf-8'))):
        return False
    return True

# %%
# Function to extract important terms using TF-IDF
def extract_important_terms(input_dir, num_terms=40, stop_words=None):
    # Load cleaned text files
    documents = []
    for file_name in os.listdir(input_dir):
        if file_name.endswith(".txt"):
            with open(os.path.join(input_dir, file_name), 'r', encoding='utf-8') as f:
                documents.append(f.read())

    # Preprocess the documents
    preprocessed_documents = [preprocess_text(doc) for doc in documents]

    # Calculate TF-IDF
    tfidf = TfidfVectorizer()
    tfidf_matrix = tfidf.fit_transform(preprocessed_documents)

    # Get feature names (terms)
    feature_names = tfidf.get_feature_names_out()

    # Get top important terms
    important_terms_indices = tfidf_matrix.sum(axis=0).argsort()[0, -num_terms:][::-1]
    important_terms = [feature_names[i] for i in important_terms_indices]

    return important_terms

# %%
# Main code
urls_file = "urls.txt"
output_dir = "scraped_text"
cleaned_output_dir = "cleaned_text"
os.makedirs(output_dir, exist_ok=True)  # Create output directory for scraped text if it doesn't exist

# Scrape text from the URLs listed in 'urls.txt'
scrape_text_and_write_to_files(urls_file, output_dir)

# Clean up the text files
clean_text_files(output_dir, cleaned_output_dir)

cleaned_text_dir = "cleaned_text"

# %%
# Extract important terms using TF-IDF
important_terms_tfidf = extract_important_terms(cleaned_text_dir, 40, stop_words)
print("Important terms extracted using TF-IDF:", important_terms_tfidf)
# Out:
# Important terms extracted using TF-IDF: [array([['american', 'video', 'time', '2024', 'folk', 'awards', 'tour',
#         'january', 'edit', 'nashville', 'new', '2017', 'july', '2015',
#         'march', 'album', 'pop', 'may', 'april', 'february', 'august',
#         'records', 'billboard', 'rock', 'swifts', 'december', '2019',
#         '2022', 'country', '2020', 'october', 'november', '2021', '2023',
#         'archived', 'original', 'music', 'retrieved', 'taylor', 'swift']],
#       dtype=object)]

# %%
# Flatten the array of terms extracted using TF-IDF
flattened_tfidf_terms = [term for sublist in important_terms_tfidf for term in sublist[0]]

# %%
# Manually determine additional important terms based on domain knowledge
additional_terms = ["Reputation", "Lover", "Red (album)", "Grammy Awards", "Country Music", "Pop Music", "Eras Tour", "Billboard charts", "1989 (album)", "Taylor Swift Foundation", "Travis Kelce", "Personal Information", "Height"]

# %%
# Combine important terms
important_terms = flattened_tfidf_terms + additional_terms

# %%
# Convert the combined terms into a list of strings
important_terms_strings = [str(term) for term in important_terms]

# %%
print("Important terms:", important_terms_strings)
# Out:
# Important terms: ['american', 'video', 'time', '2024', 'folk', 'awards', 'tour', 'january', 'edit', 'nashville', 'new', '2017', 'july', '2015', 'march', 'album', 'pop', 'may', 'april', 'february', 'august', 'records', 'billboard', 'rock', 'swifts', 'december', '2019', '2022', 'country', '2020', 'october', 'november', '2021', '2023', 'archived', 'original', 'music', 'retrieved', 'taylor', 'swift', 'Reputation', 'Lover', 'Red (album)', 'Grammy Awards', 'Country Music', 'Pop Music', 'Eras Tour', 'Billboard charts', '1989 (album)', 'Taylor Swift Foundation', 'Travis Kelce', 'Personal Information', 'Height']

# %%
# Function to load text from files and tokenize into sentences
def tokenize_sentences_from_files(input_dir):
    sentences = []
    for file_name in os.listdir(input_dir):
        if file_name.endswith(".txt"):
            with open(os.path.join(input_dir, file_name), 'r', encoding='utf-8') as f:
                text = f.read()
                # Preprocess the text to remove non-alphanumeric characters
                text = re.sub(r'\n{2,}', '\n', text)  # Collapse consecutive newlines into a single newline
                #text = re.sub(r'[^\w\s,.]', '', text)
                #text = ''.join(char for char in text if char.isalnum() or char in string.whitespace)
                sentences.extend(sent_tokenize(text))
    return sentences

# %%
# Function to build knowledge base
def build_knowledge_base(sentences, important_terms):
    knowledge_base = {term: [] for term in important_terms}
    for sentence in sentences:
        for term in important_terms:
            if term.lower() in sentence.lower():  # Case insensitive search
                knowledge_base[term].append(sentence)
    return knowledge_base

# %%
# Tokenize sentences from text files
initial_sentences = tokenize_sentences_from_files(output_dir)

# Build knowledge base
knowledge_base = build_knowledge_base(initial_sentences, important_terms_strings)

# %%
# Save the knowledge base to a file using pickle
with open('knowledge_base.pkl', 'wb') as f:
    pickle.dump(knowledge_base, f)

# %%
# Load the knowledge base from the pickle file
with open('knowledge_base.pkl', 'rb') as f:
    knowledge_base = pickle.load(f)

# Print a limited number of sentences for each term

for term, sentences_info in knowledge_base.items():
    print("Term:", term)
    for i, sentence_info in enumerate(sentences_info[:3]):  # Print only the first three sentences for each term
        print(f"Sentence {i+1}:", sentence_info)
    print()  # Add an empty line between terms
# Out:
# Term: american
# Sentence 1: Swift outside the  Late Show with David Letterman  studio in 2012
#  The American singer-songwriter  Taylor Swift  is a subject of extensive  mass media  interest and press coverage, eliciting a range of  public opinions  and perceptions of her life and career.
# Sentence 2: American  public relations  executive  Tree Paine  has been Swift's  publicist  since 2014.
# Sentence 3: She began dating American football player  Travis Kelce  in 2023, which has had a significant cultural impact, including a contribution of $331.5 million in  brand value  for the  National Football League  (NFL).
#
# Term: video
# Sentence 1: They have been featured or referenced in her  videos  and other works.
# Sentence 2: Benton characterized Swift as an unintentional but reliable "attention-grabber" whose internet media coverage has a " memetic " quality, inviting "fans and haters alike to debate and dissect her", elevating the engagements with an article or a video, which in turn encourages the media to include Swift in their content, even if it is an "awkward inclusion", to maximize their profits.
# Sentence 3: [67] [68]
#
#  Publicity and controversy [ edit ]
#  In her " You Need to Calm Down " music video, Swift critiqued the media for pitting female artists against each other by portraying  drag queens  impersonating various pop stars competing for one crown.
#
# Term: time
# Sentence 1: However,  The Guardian  opined that Swift has become "immune to hate" in the 2020s, [1]  as she remains one of the most revered and  successful music artists of all time .
# Sentence 2: Her privacy and safety has been a concern, as she is often mobbed at her leaked real-time locations, as well as incidents of armed  stalkers  and  trespassers .
# Sentence 3: [24]  However,  The New York Times  asserted in 2013 that her "dating history has begun to stir what feels like the beginning of a backlash" and questioned whether she was in the midst of a " quarter-life crisis ".
#
# Term: 2024
# Sentence 1: [45]
#
#  Position in the media [ edit ]
#  Crafts,  capitalism , conspiracies, cultural norms, the  climate crisis ; football, family relations,  fine dining ;  Argylle ,  AI ,  asbestos , academia and museums;  the US election ,  Senate  hearings, international relations and the  international date line ; romance, sexuality and the right way to be successful;  gun crime ,  Grammys  and grammar: in just the first two months of 2024,  The Guardian 's  reporting on Taylor Swift has spilled far beyond her natural home in the music section, reflecting a reach that exceeds the pop superstar's unstoppable ambitions.
# Sentence 2: [61]  Media outlets such as  USA Today  employ reporters who exclusively cover Swift; [63]   The Guardian  began a weekly  newsletter ,  Swift Notes , dedicated to Swift-related news; [46]  and the  Victoria and Albert Museum  in London looked to hire "superfan advisors" ahead of  the Eras Tour 's European leg in 2024.
# Sentence 3: [135]
#  Chiefs– Buffalo Bills  on January 21, 2024: 50.393 million viewers, marking the most-watched  NFL divisional playoff  game ever and the most-watched program on any network since the Super Bowl LVII.
#
# Term: folk
# Sentence 1: [239]
#
#  Trends [ edit ]
#  Swift's  cardigan  and  flannel  coat from  Folklore  and  Evermore  exhibited at the Country Music Hall of Fame.
# Sentence 2: [253]
#  Cottagecore  experienced a resurgence on the internet after Swift used it, [254]  increasing sales of hand-knitted  Aran jumpers  in Ireland and the U.S. [255]   RTÉ  thanked Swift for putting  cardigans  "back on the map" with  Folklore .
# Sentence 3: "Sorry, Midnights stans: Iga "Swiftie" Swiatek prefers Folklore and Evermore" .
#
# Term: awards
# Sentence 1: Perceptions [ edit ]
#  Further information:  Cultural impact of Taylor Swift § Fame and stardom , and  List of awards and nominations received by Taylor Swift § Listicles
#  Swift at the  2011 Teen Choice Awards ; she was considered a  teen idol  in her early career.
# Sentence 2: [97]
#
#  Kanye West [ edit ]
#  Kanye West  taking the microphone from Swift at the  2009 MTV Video Music Awards , with  Taylor Lautner  and  Shakira  in the background.
# Sentence 3: [98]  In September 2009, at the  2009 MTV Video Music Awards , Swift won the  MTV Video Music Award for Best Female Video  for her 2009 song " You Belong with Me ", becoming the first country singer and one of the youngest artists (age 19) to win a  MTV Video Music Award .
#
# Term: tour
# Sentence 1: [61]  Media outlets such as  USA Today  employ reporters who exclusively cover Swift; [63]   The Guardian  began a weekly  newsletter ,  Swift Notes , dedicated to Swift-related news; [46]  and the  Victoria and Albert Museum  in London looked to hire "superfan advisors" ahead of  the Eras Tour 's European leg in 2024.
# Sentence 2: [112] [113]  In response, a spokesperson for Swift stated that she had purchased more than double the required  carbon credits  to offset all tour travel and flights to visit Kelce.
# Sentence 3: [204]
#
#  Physical appearance [ edit ]
#  Body and mindset [ edit ]
#  Swift at the  1989 World Tour  (2015); she was criticized  for being "thin" and "skinny" by some general public and a number of media outlets, unbeknownst to whom she was suffering from an  eating disorder .
#
# Term: january
# Sentence 1: [135]
#  Chiefs– Buffalo Bills  on January 21, 2024: 50.393 million viewers, marking the most-watched  NFL divisional playoff  game ever and the most-watched program on any network since the Super Bowl LVII.
# Sentence 2: [136]
#  Chiefs– Baltimore Ravens  on January 28, 2024: 55.5 million viewers, marking the most watched  AFC Championship Game  of all time.
# Sentence 3: [157] [158]  At the  70th Golden Globe Awards  (January 2013), hosts  Tina Fey  and  Amy Poehler  delivered a joke about Swift, following tabloid news that week that claimed Swift had broken up with  Connor Kennedy ; Fey said that given Swift's "interest in famous guys", she should stay away from actor  Michael J.
#
# Term: edit
# Sentence 1:
#
#
#
#  Jump to content
#
#
#
#
#
#
#
#  Main menu
#
#
#
#
#
#  Main menu
#  move to sidebar
#  hide
#
#
#
# 		Navigation
#
#
#
#  Main page Contents Current events Random article About Wikipedia Contact us Donate
#
#
#
#
#
# 		Contribute
#
#
#
#  Help Learn to edit Community portal Recent changes Upload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create account
#
#  Log in
#
#
#
#
#
#
#
#
#  Personal tools
#
#
#
#
#
#    Create account   Log in
#
#
#
#
#
# 		Pages for logged out editors  learn more
#
#
#
#  Contributions Talk
#
#
#
#
#
#
#
#
#
#
#
#
#   CentralNotice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Contents
#  move to sidebar
#  hide
#
#
#
#
#  (Top)
#
#
#
#
#
#  1 Perceptions
#
#
#
#
#
#
#
#  2 Position in the media
#
#
#
#  Toggle Position in the media subsection
#
#
#
#
#
#  2.1 Publicity and controversy
#
#
#
#
#
#  2.1.1 Kanye West
#
#
#
#
#
#
#
#  2.1.2 Privacy, stalking and private jet usage
#
#
#
#
#
#
#
#
#
#
#
#  3 Sex and feminism
#
#
#
#  Toggle Sex and feminism subsection
#
#
#
#
#
#  3.1 Dating life
#
#
#
#
#
#  3.1.1 Travis Kelce
#
#
#
#
#
#
#
#
#
#  3.2 Target of misogyny
#
#
#
#
#
#
#
#  3.3 Sexual harassment
#
#
#
#
#
#
#
#  3.4 Feminist perspectives
#
#
#
#
#
#
#
#
#
#  4 Physical appearance
#
#
#
#  Toggle Physical appearance subsection
#
#
#
#
#
#  4.1 Body and mindset
#
#
#
#
#
#
#
#  4.2 Fashion and aesthetic
#
#
#
#
#
#  4.2.1 Trends
#
#
#
#
#
#
#
#
#
#
#
#  5 Politics
#
#
#
#
#
#
#
#  6 Generational appeal
#
#
#
#
#
#
#
#  7 See also
#
#
#
#
#
#
#
#  8 Note
#
#
#
#
#
#
#
#  9 References
#
#
#
#  Toggle References subsection
#
#
#
#
#
#  9.1 Cited literature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Toggle the table of contents
#
#
#
#
#
#
#
#  Public image of Taylor Swift
#
#
#
#  2 languages
#
#
#
#
#  فارسی Tiếng Việt
#
#  Edit links
#
#
#
#
#
#
#
#
#
#
#
#  Article Talk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Read Edit View history
#
#
#
#
#
#
#
#  Tools
#
#
#
#
#
#  Tools
#  move to sidebar
#  hide
#
#
#
# 		Actions
#
#
#
#  Read Edit View history
#
#
#
#
#
# 		General
#
#
#
#  What links here Related changes Upload file Special pages Permanent link Page information Cite this page Get shortened URL Download QR code Wikidata item
#
#
#
#
#
# 		Print/export
#
#
#
#  Download as PDF Printable version
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  From Wikipedia, the free encyclopedia
#
#
#  Public image of Taylor Swift
#  For her overall public influence, see  Cultural impact of Taylor Swift .
# Sentence 2: Her  private jet  usage in 2022 was criticized for its  greenhouse gas emissions , though she purchased  carbon credits to offset them .
# Sentence 3: Perceptions [ edit ]
#  Further information:  Cultural impact of Taylor Swift § Fame and stardom , and  List of awards and nominations received by Taylor Swift § Listicles
#  Swift at the  2011 Teen Choice Awards ; she was considered a  teen idol  in her early career.
#
# Term: nashville
# Sentence 1: Nashville Post .
# Sentence 2:
#
#
#
#  Jump to content
#
#
#
#
#
#
#
#  Main menu
#
#
#
#
#
#  Main menu
#  move to sidebar
#  hide
#
#
#
# 		Navigation
#
#
#
#  Main page Contents Current events Random article About Wikipedia Contact us Donate
#
#
#
#
#
# 		Contribute
#
#
#
#  Help Learn to edit Community portal Recent changes Upload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create account
#
#  Log in
#
#
#
#
#
#
#
#
#  Personal tools
#
#
#
#
#
#    Create account   Log in
#
#
#
#
#
# 		Pages for logged out editors  learn more
#
#
#
#  Contributions Talk
#
#
#
#
#
#
#
#
#
#
#
#
#   CentralNotice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Contents
#  move to sidebar
#  hide
#
#
#
#
#  (Top)
#
#
#
#
#
#  1 Origins
#
#
#
#  Toggle Origins subsection
#
#
#
#
#
#  1.1 Role of East Tennessee
#
#
#
#
#
#
#
#
#
#  2 Generations
#
#
#
#
#
#
#
#  3 History
#
#
#
#  Toggle History subsection
#
#
#
#
#
#  3.1 First generation (1920s)
#
#
#
#
#
#
#
#  3.2 Second generation (1930s–1940s)
#
#
#
#
#
#  3.2.1 Singing cowboys and western swing
#
#
#
#
#
#
#
#  3.2.2 Changing instrumentation
#
#
#
#
#
#
#
#  3.2.3 Hillbilly boogie
#
#
#
#
#
#
#
#  3.2.4 Bluegrass, folk and gospel
#
#
#
#
#
#
#
#  3.2.5 Honky tonk
#
#
#
#
#
#
#
#
#
#  3.3 Third generation (1950s–1960s)
#
#
#
#
#
#  3.3.1 Rockabilly
#
#
#
#
#
#
#
#  3.3.2 The Nashville and countrypolitan sounds
#
#
#
#
#
#
#
#  3.3.3 Country-soul crossover
#
#
#
#
#
#
#
#  3.3.4 Bakersfield sound
#
#
#
#
#
#
#
#
#
#  3.4 Western music merges with country
#
#
#
#
#
#
#
#  3.5 Fourth generation (1970s–1980s)
#
#
#
#
#
#  3.5.1 Outlaw movement
#
#
#
#
#
#
#
#  3.5.2 Country pop
#
#
#
#
#
#
#
#  3.5.3 Country rock
#
#
#
#
#
#
#
#  3.5.4 Neocountry
#
#
#
#
#
#
#
#  3.5.5 Truck driving country
#
#
#
#
#
#
#
#  3.5.6 Neotraditionalist movement
#
#
#
#
#
#
#
#
#
#  3.6 Fifth generation (1990s)
#
#
#
#
#
#  3.6.1 Success of female artists
#
#
#
#
#
#
#
#  3.6.2 Line dancing revival
#
#
#
#
#
#
#
#  3.6.3 Alternative country
#
#
#
#
#
#
#
#
#
#  3.7 Sixth generation (2000s–present)
#
#
#
#
#
#  3.7.1 Popular culture
#
#
#
#
#
#
#
#  3.7.2 Modern variations
#
#
#
#
#
#  3.7.2.1 Influence of rock, pop and hip-hop
#
#
#
#
#
#  3.7.2.1.1 Bro country
#
#
#
#
#
#
#
#
#
#  3.7.2.2 Bluegrass and Americana
#
#
#
#
#
#
#
#  3.7.2.3 Contemporary country and western revival
#
#
#
#
#
#
#
#
#
#
#
#
#
#  4 International
#
#
#
#  Toggle International subsection
#
#
#
#
#
#  4.1 Australia
#
#
#
#
#
#
#
#  4.2 Canada
#
#
#
#
#
#
#
#  4.3 Mexico and Latin America
#
#
#
#
#
#
#
#  4.4 United Kingdom
#
#
#
#
#
#
#
#  4.5 Ireland
#
#
#
#
#
#
#
#  4.6 Japan and Asia
#
#
#
#
#
#
#
#  4.7 Other international country music
#
#
#
#
#
#  4.7.1 Middle East
#
#
#
#
#
#
#
#  4.7.2 Continental Europe
#
#
#
#
#
#
#
#
#
#
#
#  5 Performers and shows
#
#
#
#  Toggle Performers and shows subsection
#
#
#
#
#
#  5.1 US cable television
#
#
#
#
#
#
#
#  5.2 Canadian television
#
#
#
#
#
#
#
#  5.3 Australian cable television
#
#
#
#
#
#
#
#  5.4 British digital television
#
#
#
#
#
#
#
#  5.5 Festivals
#
#
#
#
#
#
#
#
#
#  6 Culture
#
#
#
#  Toggle Culture subsection
#
#
#
#
#
#  6.1 Race in modern country music
#
#
#
#
#
#
#
#
#
#  7 See also
#
#
#
#
#
#
#
#  8 References
#
#
#
#
#
#
#
#  9 Further reading
#
#
#
#
#
#
#
#  10 External links
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Toggle the table of contents
#
#
#
#
#
#
#
#  Country music
#
#
#
#  83 languages
#
#
#
#
#  Alemannisch العربية Asturianu Azərbaycanca Беларуская Беларуская (тарашкевіца) Български Bosanski Català Cebuano Čeština Cymraeg Dansk Deutsch Eesti Ελληνικά Español Esperanto Euskara فارسی Føroyskt Français Frysk Gaeilge Gàidhlig Galego 한국어 Հայերեն हिन्दी Hrvatski Ido Bahasa Indonesia Interlingua Íslenska Italiano עברית ಕನ್ನಡ ქართული Kiswahili Latina Latviešu Lietuvių Limburgs Lingua Franca Nova Magyar Македонски മലയാളം مصرى Bahasa Melayu Монгол မြန်မာဘာသာ Nederlands Nedersaksies 日本語 Norsk bokmål Norsk nynorsk Occitan Oʻzbekcha / ўзбекча Polski Português Română Русский Саха тыла Sicilianu සිංහල Simple English Slovenčina Slovenščina کوردی Српски / srpski Srpskohrvatski / српскохрватски Suomi Svenska Tagalog ไทย Türkçe Удмурт Українська Tiếng Việt 吴语 ייִדיש 粵語 中文
#
#  Edit links
#
#
#
#
#
#
#
#
#
#
#
#  Article Talk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Read Edit View history
#
#
#
#
#
#
#
#  Tools
#
#
#
#
#
#  Tools
#  move to sidebar
#  hide
#
#
#
# 		Actions
#
#
#
#  Read Edit View history
#
#
#
#
#
# 		General
#
#
#
#  What links here Related changes Upload file Special pages Permanent link Page information Cite this page Get shortened URL Download QR code Wikidata item
#
#
#
#
#
# 		Print/export
#
#
#
#  Download as PDF Printable version
#
#
#
#
#
# 		In other projects
#
#
#
#  Wikimedia Commons Wikinews Wikiquote Wikiversity
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  From Wikipedia, the free encyclopedia
#
#
#  American music genre
#  This article is about the music genre.
# Sentence 3: Find sources:   "Country music"  –  news   ·   newspapers   ·   books   ·   scholar   ·   JSTOR   ( December 2022 )  ( Learn how and when to remove this message )
#
#
#  Country Other names Country and western Stylistic origins
#  American folk  and  western
#  Appalachian
#  African-American
#  Cajun
#  Creole
#  Hawaiian
#  New Mexico
#  red dirt
#  Tejano
#  blues
#  southern gospel
#  old-time
#  Cultural origins 1920s,  Southern United States Typical instruments Acoustic Guitar
#  Electric Guitar
#  Pedal Steel Guitar
#  Lap Steel Guitar
#  Fiddle
#  Harmonica
#  Drums
#  Vocals
#  Piano
#  Upright Bass
#
#  Bass Guitar Derivative forms
#  Bluegrass
#  cowboy pop
#  dansband
#  rock and roll
#  swamp pop
#  Tulsa sound
#  zydeco
#  Subgenres
#  Alternative
#  Christian
#  gothic
#  honky-tonk
#  neo-traditional
#  outlaw
#  progressive
#  truck-driving
#  western swing
#  ( complete list ) Fusion genres
#  Country folk
#  country rap
#  country rock
#  country pop
#  bro-country
#  cowpunk
#  Gulf and western
#  rockabilly
#  gothabilly
#  psychobilly
#  southern soul
#  swamp rock [1]
#  Regional scenes
#  Australia
#  Canada
#  Ireland
#  Local scenes
#  Bakersfield
#  Nashville
#  Other topics
#  Contemporary folk music
#  country music by year
#  country musicians
#  country–western dance
#  radio formats
#  classic country
#  regional Mexican
#  singing cowboy
#  yodeling
#    2024 in country music
#  Country  (also called  country and western ) is a  music genre  originating in the southern regions of the United States, both the  American South  and  the Southwest .
#
# Term: new
# Sentence 1: The public has shown a heightened interest in news about Swift, which has encouraged media outlets to hyperfocus on her.
# Sentence 2: [24]  However,  The New York Times  asserted in 2013 that her "dating history has begun to stir what feels like the beginning of a backlash" and questioned whether she was in the midst of a " quarter-life crisis ".
# Sentence 3: [50]  News magazine  Time 's 2023  Person of the Year  issue featuring Swift sold 238,808 physical copies, not including  newsstand  sales, marking the highest-selling  Time  issue since the May 2011 issue that featured the royal  wedding of Prince William and Catherine Middleton , which sold 232,000 copies from the website and the newsstands combined.
#
# Term: 2017
# Sentence 1: [60]
#  Critics have described the relationship between Swift and the  mainstream media  as an example of the  celebrity–industrial complex , [61]  which in turn has affected Swift's art profusely; her sixth studio album  Reputation  (2017), whose subject matter is fame, critiques the complex, [62]  while her autobiographical documentary  Miss Americana  (2020) deconstructs it.
# Sentence 2: [73]  Swift has generally used negative critique as musical inspiration, writing songs such as " Shake It Off " (2014), " Look What You Made Me Do " (2017), and " You Need to Calm Down " (2019).
# Sentence 3: [75]  Paine has received press coverage for guiding Swift through a number of publicized moments, such as Swift's 2016 controversy with West following the release of his single " Famous ",  her 2017 sexual assault trial , her choice to speak on politics for the  2018 U.S. mid-term elections , the  2019 dispute over her masters , [76] [77] [78]  and a 2023 series of claims about Swift by  celebrity gossip  social media account  DeuxMoi .
#
# Term: july
# Sentence 1: ^   Steele, Anne (July 1, 2023).
# Sentence 2: Archived  from the original on July 2, 2023 .
# Sentence 3: Retrieved  July 2,  2023 .
#
# Term: 2015
# Sentence 1: Oprah Winfrey  on Swift,  Herald Sun  (2015) [9]
#
#  Critical commentary often refers to Swift as an uncommon,  monocultural  entity, [10] [11]  or more often "the most famous person on the planet".
# Sentence 2: Swift and West posed together in photographs from the  57th Annual Grammy Awards  in 2015, and she stated that they had become friends with help from  Jay-Z , a mutual friend.
# Sentence 3: [106]  In 2015, Swift's fans swarmed the  Narita International Airport  in  Chiba , Japan, when she landed there, causing flight delays.
#
# Term: march
# Sentence 1: Happy Women's History Month I guess
#
#
#
#  March 1, 2021 [167]
#
#
#
#
#
#  On March 1, 2021, Swift criticized the writers of Netflix series  Ginny & Georgia  for using a "lazy, deeply sexist joke" slut-shaming her.
# Sentence 2: Archived  from the original on March 1, 2021 .
# Sentence 3: Archived  from the original on March 18, 2023 .
#
# Term: album
# Sentence 1: The negative media reception inspired a significant number of  her songs , [note 2]  including the core concept of Swift's sixth studio album,  Reputation .
# Sentence 2: [60]
#  Critics have described the relationship between Swift and the  mainstream media  as an example of the  celebrity–industrial complex , [61]  which in turn has affected Swift's art profusely; her sixth studio album  Reputation  (2017), whose subject matter is fame, critiques the complex, [62]  while her autobiographical documentary  Miss Americana  (2020) deconstructs it.
# Sentence 3: [98]
#
#  Snake , a term that was used by detractors to ridicule Swift in 2016, became the main visual  motif  of her 2017 album  Reputation .
#
# Term: pop
# Sentence 1: Swift has been described as a savvy businesswoman,  feminist  figure,  political influencer ,  millennial  exemplar and a  street style  icon in the media;  her philanthropic efforts , activism for  artists' rights , closeness with fans, and  impact on popular culture and the music industry  have been topics of praise.
# Sentence 2: [3]  She is considered a dominant figure in  popular culture , [4]  often referred to as a  pop icon ; [5] [6]  publications note her immense popularity and longevity as the kind of fame unwitnessed since the 20th century.
# Sentence 3: [12] [13]  In the words of music critics  Sam Sanders  and  Ann Powers , Swift is a "surprisingly successful composite of megawatt pop star and bedroom singer-songwriter."
#
# Term: may
# Sentence 1: Highly publicized disputes, such as those with  Kanye West ,  Katy Perry  and  Kim Kardashian , and breakups with romantic partners such as  Joe Jonas ,  John Mayer ,  Jake Gyllenhaal ,  Harry Styles , and  Tom Hiddleston  affected her public perception in the 2010s, contributing to a tarnish of her image.
# Sentence 2: [50]  News magazine  Time 's 2023  Person of the Year  issue featuring Swift sold 238,808 physical copies, not including  newsstand  sales, marking the highest-selling  Time  issue since the May 2011 issue that featured the royal  wedding of Prince William and Catherine Middleton , which sold 232,000 copies from the website and the newsstands combined.
# Sentence 3: Animosity alleged by media outlets also contest Swift against  Cardi B , [87]   Adele , [88]   Demi Lovato , [89]   SZA , [90]  and  Ariana Grande —despite the fact that Swift engaged none of them and even attempted to quash some of the rumors [91] —and against her former boyfriends  Joe Jonas ,  John Mayer ,  Calvin Harris , [83]  and  Jake Gyllenhaal .
#
# Term: april
# Sentence 1: Archived  from the original on April 28, 2022 .
# Sentence 2: Archived  from the original on April 22, 2022 .
# Sentence 3: ^   Armanini, Kate (April 12, 2023).
#
# Term: february
# Sentence 1: [137]
#  Chiefs– San Francisco 49ers  ( Super Bowl LVIII ) on February 11, 2024: 123.4 millions viewers on  CBS / Paramount+  and 202.4 million total viewers, marking  the most watched non-news telecast of all time  and the most watched broadcast since the  Apollo 11  moon landing.
# Sentence 2: Archived  from the original on February 18, 2022 .
# Sentence 3: Archived  from the original on February 8, 2023 .
#
# Term: august
# Sentence 1: [121] [127]
#
#  Travis Kelce [ edit ]
#  American football player  Travis Kelce  in 2021
#  Swift began dating  American football  player  Travis Kelce  around August 2023.
# Sentence 2: [165]
#
#  Sexual harassment [ edit ]
#  In August 2017,  a sexual assault trial  was held in the  United States District Court for the District of Colorado , involving former DJ David Mueller, a  KYGO-FM  radio employee, who filed for  defamation  against Swift.
# Sentence 3: ^   Levine, Nick (August 21, 2019).
#
# Term: records
# Sentence 1: [51]
#  Shows and television programs featuring her often attain viewership peaks; [52] [53]  for instance, Swift's presence at a number of  National Football League  (NFL) games broke a series of viewership, ticket and merchandise sales records for the league, network and television, referred to as the "Taylor Swift effect".
# Sentence 2: [128]  The NFL games of Kelce's team, the  Kansas City Chiefs , that were attended by Swift broke a number of viewership records, including record high female viewership.
# Sentence 3: [133]  Some of the records broken by the games attended by Swift include:
#
#  Chiefs– Chicago Bears  on September 24, 2023: 24.32 million viewers on  Fox Sports , the most television viewers of the weekend.
#
# Term: billboard
# Sentence 1: The romantic relationship has had a cultural impact, about which  Billboard  opined that the two "are arguably the world's most high-profile couple right now, consistently making headlines on the daily for simply holding hands or enjoying dinner together."
# Sentence 2: Billboard .
# Sentence 3: Billboard .
#
# Term: rock
# Sentence 1: However, Rosen also stated that there is "a  sexist   double standard  in the policing of Swift's confessions, especially when you consider the routine misogyny in the songs of rockers, rappers, and woebegone beardy indie balladeers."
# Sentence 2: [251]  According to  Rob Sheffield , the scarf is so significant to Swift's discography that it "should be in the  Rock and Roll Hall of Fame ."
# Sentence 3: [273]  Awarding Swift for her humanitarian endeavors in 2012, former  First Lady  of the U.S.,  Michelle Obama , described Swift as an artist who "has rocketed to the top of the music industry but still keeps her feet on the ground, someone who has shattered every expectation of what a 22-year-old can accomplish".
#
# Term: swifts
# Sentence 1: "Why Do We Celebrate The Pete Davidsons But Not The Taylor Swifts?"
# Sentence 2: #taylorswift #taylorswiftsongs #taylornation #CDs" .
#
# Term: december
# Sentence 1: [114] [115]  In December 2023, Swift's lawyers sent a  cease and desist  letter to American programmer  Jack Sweeney , the person who owned the jet-tracking accounts, alleging stalking and safety risks; media outlets have reported that the information posted by Sweeney is a synthesis of publicly available data.
# Sentence 2: [175]  In December 2017, Swift was named a "Silence Breaker" in  Time  magazine's  Person of the Year  issue.
# Sentence 3: ^   Yahr, Emily (December 26, 2022).
#
# Term: 2019
# Sentence 1: [30] [31]  Nevertheless, between 2019 and 2021,  YouGov  surveys ranked her as the world's most admired female musician.
# Sentence 2: [73]  Swift has generally used negative critique as musical inspiration, writing songs such as " Shake It Off " (2014), " Look What You Made Me Do " (2017), and " You Need to Calm Down " (2019).
# Sentence 3: [75]  Paine has received press coverage for guiding Swift through a number of publicized moments, such as Swift's 2016 controversy with West following the release of his single " Famous ",  her 2017 sexual assault trial , her choice to speak on politics for the  2018 U.S. mid-term elections , the  2019 dispute over her masters , [76] [77] [78]  and a 2023 series of claims about Swift by  celebrity gossip  social media account  DeuxMoi .
#
# Term: 2022
# Sentence 1: Her  private jet  usage in 2022 was criticized for its  greenhouse gas emissions , though she purchased  carbon credits to offset them .
# Sentence 2: [111]
#  Swift's  private jet  use has drawn scrutiny and criticism for its  carbon emissions  after media outlets cited a 2022 report which was compiled based on data posted by the now-defunct Twitter account @CelebJets.
# Sentence 3: [126]  Many of her songs address feminist themes; examples include " I Did Something Bad " (2017), " The Man " (2019), " The Last Great American Dynasty " (2020), " Mad Woman " (2020), " Vigilante Shit " (2022), and " Would've, Could've, Should've " (2022).
#
# Term: country
# Sentence 1: In her early career as a  country  singer in the late 2000s decade, Swift was referred to as " America's Sweetheart " as a result of her  girl next door  image.
# Sentence 2: [93]
#  Knibbs commented that Swift was a "country music princess on the verge of superstardom" in 2009, became a "snake" in 2016, and returned as a "full-blown music juggernaut" after 2019, providing an excellent "case study for the ups and downs of modern pop stardom".
# Sentence 3: [98]  In September 2009, at the  2009 MTV Video Music Awards , Swift won the  MTV Video Music Award for Best Female Video  for her 2009 song " You Belong with Me ", becoming the first country singer and one of the youngest artists (age 19) to win a  MTV Video Music Award .
#
# Term: 2020
# Sentence 1: However,  The Guardian  opined that Swift has become "immune to hate" in the 2020s, [1]  as she remains one of the most revered and  successful music artists of all time .
# Sentence 2: [60]
#  Critics have described the relationship between Swift and the  mainstream media  as an example of the  celebrity–industrial complex , [61]  which in turn has affected Swift's art profusely; her sixth studio album  Reputation  (2017), whose subject matter is fame, critiques the complex, [62]  while her autobiographical documentary  Miss Americana  (2020) deconstructs it.
# Sentence 3: [95]  According to Carter Sherman of  Vice , after viewing Swift as a "villain" from 2016 to 2018, growing  self-awareness  in the media helped popular culture undergo a "Great Swift Revival" in 2020, healing her public image.
#
# Term: october
# Sentence 1: [134]
#  Chiefs– New York Jets  on October 1, 2023: 27 million viewers across all  NBC  broadcasts, making it the most-watched Sunday-night television show since  Super Bowl LVII .
# Sentence 2: [162]  In October 2014, on Australian radio show  Jules, Merrick & Sophie , Swift stated she is "unfairly criticized" for her lyrics compared to her male peers: [163]
#
#  "You're going to have people who are going to say, 'Oh, you know, like, she just writes songs about her ex-boyfriends.'
# Sentence 3: Retrieved  October 29,  2021 .
#
# Term: november
# Sentence 1: Swift joked about the incident in her  Saturday Night Live  monologue in November 2009.
# Sentence 2: [147]  A television special by  Nightline  about the relationship and its impact, titled  Taylor + Travis , was released on  Hulu  in November 2023.
# Sentence 3: Retrieved  November 12,  2023 .
#
# Term: 2021
# Sentence 1: [30] [31]  Nevertheless, between 2019 and 2021,  YouGov  surveys ranked her as the world's most admired female musician.
# Sentence 2: [58]  The episode of dance competition program  Dancing With the Stars  that paid tribute to Swift amassed a record 7.8 million viewers across all official platforms, making it the show's most-watched multi-platform telecast on  ABC  since its September 2021 premiere.
# Sentence 3: [121] [127]
#
#  Travis Kelce [ edit ]
#  American football player  Travis Kelce  in 2021
#  Swift began dating  American football  player  Travis Kelce  around August 2023.
#
# Term: 2023
# Sentence 1: Her estimated  earned media  value is US$130 billion as of 2023.
# Sentence 2: She began dating American football player  Travis Kelce  in 2023, which has had a significant cultural impact, including a contribution of $331.5 million in  brand value  for the  National Football League  (NFL).
# Sentence 3: [50]  News magazine  Time 's 2023  Person of the Year  issue featuring Swift sold 238,808 physical copies, not including  newsstand  sales, marking the highest-selling  Time  issue since the May 2011 issue that featured the royal  wedding of Prince William and Catherine Middleton , which sold 232,000 copies from the website and the newsstands combined.
#
# Term: archived
# Sentence 1: Archived  from the original on September 8, 2023 .
# Sentence 2: Archived  from the original on April 28, 2022 .
# Sentence 3: Archived  from the original on February 18, 2022 .
#
# Term: original
# Sentence 1: Archived  from the original on September 8, 2023 .
# Sentence 2: Archived  from the original on April 28, 2022 .
# Sentence 3: Archived  from the original on February 18, 2022 .
#
# Term: music
# Sentence 1: However,  The Guardian  opined that Swift has become "immune to hate" in the 2020s, [1]  as she remains one of the most revered and  successful music artists of all time .
# Sentence 2: Swift has been described as a savvy businesswoman,  feminist  figure,  political influencer ,  millennial  exemplar and a  street style  icon in the media;  her philanthropic efforts , activism for  artists' rights , closeness with fans, and  impact on popular culture and the music industry  have been topics of praise.
# Sentence 3: [12] [13]  In the words of music critics  Sam Sanders  and  Ann Powers , Swift is a "surprisingly successful composite of megawatt pop star and bedroom singer-songwriter."
#
# Term: retrieved
# Sentence 1: Retrieved  November 12,  2023 .
# Sentence 2: Retrieved  May 20,  2021 .
# Sentence 3: Retrieved  May 13,  2021 .
#
# Term: taylor
# Sentence 1:
#
#
#
#  Jump to content
#
#
#
#
#
#
#
#  Main menu
#
#
#
#
#
#  Main menu
#  move to sidebar
#  hide
#
#
#
# 		Navigation
#
#
#
#  Main page Contents Current events Random article About Wikipedia Contact us Donate
#
#
#
#
#
# 		Contribute
#
#
#
#  Help Learn to edit Community portal Recent changes Upload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create account
#
#  Log in
#
#
#
#
#
#
#
#
#  Personal tools
#
#
#
#
#
#    Create account   Log in
#
#
#
#
#
# 		Pages for logged out editors  learn more
#
#
#
#  Contributions Talk
#
#
#
#
#
#
#
#
#
#
#
#
#   CentralNotice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Contents
#  move to sidebar
#  hide
#
#
#
#
#  (Top)
#
#
#
#
#
#  1 Perceptions
#
#
#
#
#
#
#
#  2 Position in the media
#
#
#
#  Toggle Position in the media subsection
#
#
#
#
#
#  2.1 Publicity and controversy
#
#
#
#
#
#  2.1.1 Kanye West
#
#
#
#
#
#
#
#  2.1.2 Privacy, stalking and private jet usage
#
#
#
#
#
#
#
#
#
#
#
#  3 Sex and feminism
#
#
#
#  Toggle Sex and feminism subsection
#
#
#
#
#
#  3.1 Dating life
#
#
#
#
#
#  3.1.1 Travis Kelce
#
#
#
#
#
#
#
#
#
#  3.2 Target of misogyny
#
#
#
#
#
#
#
#  3.3 Sexual harassment
#
#
#
#
#
#
#
#  3.4 Feminist perspectives
#
#
#
#
#
#
#
#
#
#  4 Physical appearance
#
#
#
#  Toggle Physical appearance subsection
#
#
#
#
#
#  4.1 Body and mindset
#
#
#
#
#
#
#
#  4.2 Fashion and aesthetic
#
#
#
#
#
#  4.2.1 Trends
#
#
#
#
#
#
#
#
#
#
#
#  5 Politics
#
#
#
#
#
#
#
#  6 Generational appeal
#
#
#
#
#
#
#
#  7 See also
#
#
#
#
#
#
#
#  8 Note
#
#
#
#
#
#
#
#  9 References
#
#
#
#  Toggle References subsection
#
#
#
#
#
#  9.1 Cited literature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Toggle the table of contents
#
#
#
#
#
#
#
#  Public image of Taylor Swift
#
#
#
#  2 languages
#
#
#
#
#  فارسی Tiếng Việt
#
#  Edit links
#
#
#
#
#
#
#
#
#
#
#
#  Article Talk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Read Edit View history
#
#
#
#
#
#
#
#  Tools
#
#
#
#
#
#  Tools
#  move to sidebar
#  hide
#
#
#
# 		Actions
#
#
#
#  Read Edit View history
#
#
#
#
#
# 		General
#
#
#
#  What links here Related changes Upload file Special pages Permanent link Page information Cite this page Get shortened URL Download QR code Wikidata item
#
#
#
#
#
# 		Print/export
#
#
#
#  Download as PDF Printable version
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  From Wikipedia, the free encyclopedia
#
#
#  Public image of Taylor Swift
#  For her overall public influence, see  Cultural impact of Taylor Swift .
# Sentence 2: Swift outside the  Late Show with David Letterman  studio in 2012
#  The American singer-songwriter  Taylor Swift  is a subject of extensive  mass media  interest and press coverage, eliciting a range of  public opinions  and perceptions of her life and career.
# Sentence 3: Perceptions [ edit ]
#  Further information:  Cultural impact of Taylor Swift § Fame and stardom , and  List of awards and nominations received by Taylor Swift § Listicles
#  Swift at the  2011 Teen Choice Awards ; she was considered a  teen idol  in her early career.
#
# Term: swift
# Sentence 1:
#
#
#
#  Jump to content
#
#
#
#
#
#
#
#  Main menu
#
#
#
#
#
#  Main menu
#  move to sidebar
#  hide
#
#
#
# 		Navigation
#
#
#
#  Main page Contents Current events Random article About Wikipedia Contact us Donate
#
#
#
#
#
# 		Contribute
#
#
#
#  Help Learn to edit Community portal Recent changes Upload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create account
#
#  Log in
#
#
#
#
#
#
#
#
#  Personal tools
#
#
#
#
#
#    Create account   Log in
#
#
#
#
#
# 		Pages for logged out editors  learn more
#
#
#
#  Contributions Talk
#
#
#
#
#
#
#
#
#
#
#
#
#   CentralNotice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Contents
#  move to sidebar
#  hide
#
#
#
#
#  (Top)
#
#
#
#
#
#  1 Perceptions
#
#
#
#
#
#
#
#  2 Position in the media
#
#
#
#  Toggle Position in the media subsection
#
#
#
#
#
#  2.1 Publicity and controversy
#
#
#
#
#
#  2.1.1 Kanye West
#
#
#
#
#
#
#
#  2.1.2 Privacy, stalking and private jet usage
#
#
#
#
#
#
#
#
#
#
#
#  3 Sex and feminism
#
#
#
#  Toggle Sex and feminism subsection
#
#
#
#
#
#  3.1 Dating life
#
#
#
#
#
#  3.1.1 Travis Kelce
#
#
#
#
#
#
#
#
#
#  3.2 Target of misogyny
#
#
#
#
#
#
#
#  3.3 Sexual harassment
#
#
#
#
#
#
#
#  3.4 Feminist perspectives
#
#
#
#
#
#
#
#
#
#  4 Physical appearance
#
#
#
#  Toggle Physical appearance subsection
#
#
#
#
#
#  4.1 Body and mindset
#
#
#
#
#
#
#
#  4.2 Fashion and aesthetic
#
#
#
#
#
#  4.2.1 Trends
#
#
#
#
#
#
#
#
#
#
#
#  5 Politics
#
#
#
#
#
#
#
#  6 Generational appeal
#
#
#
#
#
#
#
#  7 See also
#
#
#
#
#
#
#
#  8 Note
#
#
#
#
#
#
#
#  9 References
#
#
#
#  Toggle References subsection
#
#
#
#
#
#  9.1 Cited literature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Toggle the table of contents
#
#
#
#
#
#
#
#  Public image of Taylor Swift
#
#
#
#  2 languages
#
#
#
#
#  فارسی Tiếng Việt
#
#  Edit links
#
#
#
#
#
#
#
#
#
#
#
#  Article Talk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Read Edit View history
#
#
#
#
#
#
#
#  Tools
#
#
#
#
#
#  Tools
#  move to sidebar
#  hide
#
#
#
# 		Actions
#
#
#
#  Read Edit View history
#
#
#
#
#
# 		General
#
#
#
#  What links here Related changes Upload file Special pages Permanent link Page information Cite this page Get shortened URL Download QR code Wikidata item
#
#
#
#
#
# 		Print/export
#
#
#
#  Download as PDF Printable version
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  From Wikipedia, the free encyclopedia
#
#
#  Public image of Taylor Swift
#  For her overall public influence, see  Cultural impact of Taylor Swift .
# Sentence 2: Swift outside the  Late Show with David Letterman  studio in 2012
#  The American singer-songwriter  Taylor Swift  is a subject of extensive  mass media  interest and press coverage, eliciting a range of  public opinions  and perceptions of her life and career.
# Sentence 3: [note 1]
#  Swift is an omnipresent but polarizing  cultural figure  whose public image is defined by the  sociological  relationships between her,  her large fandom , detractors, and the  mainstream media .
#
# Term: Reputation
# Sentence 1: The negative media reception inspired a significant number of  her songs , [note 2]  including the core concept of Swift's sixth studio album,  Reputation .
# Sentence 2: [17]
#
#  Swift interviewed by  YouTube  executive Kevin Allocca in 2011
#  Labeled by the media as " America's Sweetheart " in her early career for her likability and  girl-next-door  image; [18] [19]  Swift earned a reputation for her enthusiasm at award shows.
# Sentence 3: [60]
#  Critics have described the relationship between Swift and the  mainstream media  as an example of the  celebrity–industrial complex , [61]  which in turn has affected Swift's art profusely; her sixth studio album  Reputation  (2017), whose subject matter is fame, critiques the complex, [62]  while her autobiographical documentary  Miss Americana  (2020) deconstructs it.
#
# Term: Lover
# Sentence 1: "Taylor Swift's  Lover : The struggle to maintain superstardom" .
# Sentence 2: "How Taylor Swift's 'Lover' rollout blurred the personal and promotional" .
# Sentence 3: "Taylor Swift's  Lover : The struggle to maintain superstardom" .
#
# Term: Red (album)
#
# Term: Grammy Awards
# Sentence 1: Swift and West posed together in photographs from the  57th Annual Grammy Awards  in 2015, and she stated that they had become friends with help from  Jay-Z , a mutual friend.
# Sentence 2: After Swift "shaded" West in her speech following her  Album of the Year  win for  1989  at the  58th Annual Grammy Awards  (2016), talking about not letting detractors take credit for her fame, West's then-wife,  Kim Kardashian , released trimmed clips of the Swift–West call on  Snapchat  that appeared to support West's claim.
# Sentence 3: Shania Twain  has been nominated eighteen times for  Grammy Awards  and won five Grammys.
#
# Term: Country Music
# Sentence 1: [93]
#  Knibbs commented that Swift was a "country music princess on the verge of superstardom" in 2009, became a "snake" in 2016, and returned as a "full-blown music juggernaut" after 2019, providing an excellent "case study for the ups and downs of modern pop stardom".
# Sentence 2: [239]
#
#  Trends [ edit ]
#  Swift's  cardigan  and  flannel  coat from  Folklore  and  Evermore  exhibited at the Country Music Hall of Fame.
# Sentence 3: "Taylor Swift Left a Blank Space in Country Music.
#
# Term: Pop Music
# Sentence 1: "Pop music in the era of Taylor Swift: Behind the success of today's biggest star" .
# Sentence 2: "Taylor Swift: 'Pop music can feel like it's The Hunger Games, and like we're gladiators' " .
# Sentence 3: Rendering was triggered because: page-view
#
#  esi <esi:include src="/esitest-fa8a495983347898/content" />
#  Retrieved from " https://en.wikipedia.org/w/index.php?title=Public_image_of_Taylor_Swift&oldid=1221122091 "
#  Categories :  Taylor Swift 2000s in music 2010s in music 2020s in music Public image by individuals Cultural depictions of pop musicians Hidden categories:  Articles with short description Short description is different from Wikidata Use American English from January 2024 All Wikipedia articles written in American English Use mdy dates from January 2024 Pages using multiple image with auto scaled images
#
#
#
#
#
#
#   This page was last edited on 28 April 2024, at 00:49  (UTC) .
#
# Term: Eras Tour
# Sentence 1: [61]  Media outlets such as  USA Today  employ reporters who exclusively cover Swift; [63]   The Guardian  began a weekly  newsletter ,  Swift Notes , dedicated to Swift-related news; [46]  and the  Victoria and Albert Museum  in London looked to hire "superfan advisors" ahead of  the Eras Tour 's European leg in 2024.
# Sentence 2: [257]  The Eras Tour increased the demand for metallic  boots ,  cowboy hats , and  sequin  dresses.
# Sentence 3: "2023 Artist of the Year Taylor Swift Built the Perfect Machine with "The Eras Tour" .
#
# Term: Billboard charts
# Sentence 1: ^   "Lil Nas X hit 'Old Town Road' makes Billboard charts history" .
#
# Term: 1989 (album)
#
# Term: Taylor Swift Foundation
#
# Term: Travis Kelce
# Sentence 1:
#
#
#
#  Jump to content
#
#
#
#
#
#
#
#  Main menu
#
#
#
#
#
#  Main menu
#  move to sidebar
#  hide
#
#
#
# 		Navigation
#
#
#
#  Main page Contents Current events Random article About Wikipedia Contact us Donate
#
#
#
#
#
# 		Contribute
#
#
#
#  Help Learn to edit Community portal Recent changes Upload file
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#  Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Create account
#
#  Log in
#
#
#
#
#
#
#
#
#  Personal tools
#
#
#
#
#
#    Create account   Log in
#
#
#
#
#
# 		Pages for logged out editors  learn more
#
#
#
#  Contributions Talk
#
#
#
#
#
#
#
#
#
#
#
#
#   CentralNotice
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Contents
#  move to sidebar
#  hide
#
#
#
#
#  (Top)
#
#
#
#
#
#  1 Perceptions
#
#
#
#
#
#
#
#  2 Position in the media
#
#
#
#  Toggle Position in the media subsection
#
#
#
#
#
#  2.1 Publicity and controversy
#
#
#
#
#
#  2.1.1 Kanye West
#
#
#
#
#
#
#
#  2.1.2 Privacy, stalking and private jet usage
#
#
#
#
#
#
#
#
#
#
#
#  3 Sex and feminism
#
#
#
#  Toggle Sex and feminism subsection
#
#
#
#
#
#  3.1 Dating life
#
#
#
#
#
#  3.1.1 Travis Kelce
#
#
#
#
#
#
#
#
#
#  3.2 Target of misogyny
#
#
#
#
#
#
#
#  3.3 Sexual harassment
#
#
#
#
#
#
#
#  3.4 Feminist perspectives
#
#
#
#
#
#
#
#
#
#  4 Physical appearance
#
#
#
#  Toggle Physical appearance subsection
#
#
#
#
#
#  4.1 Body and mindset
#
#
#
#
#
#
#
#  4.2 Fashion and aesthetic
#
#
#
#
#
#  4.2.1 Trends
#
#
#
#
#
#
#
#
#
#
#
#  5 Politics
#
#
#
#
#
#
#
#  6 Generational appeal
#
#
#
#
#
#
#
#  7 See also
#
#
#
#
#
#
#
#  8 Note
#
#
#
#
#
#
#
#  9 References
#
#
#
#  Toggle References subsection
#
#
#
#
#
#  9.1 Cited literature
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Toggle the table of contents
#
#
#
#
#
#
#
#  Public image of Taylor Swift
#
#
#
#  2 languages
#
#
#
#
#  فارسی Tiếng Việt
#
#  Edit links
#
#
#
#
#
#
#
#
#
#
#
#  Article Talk
#
#
#
#
#
#  English
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Read Edit View history
#
#
#
#
#
#
#
#  Tools
#
#
#
#
#
#  Tools
#  move to sidebar
#  hide
#
#
#
# 		Actions
#
#
#
#  Read Edit View history
#
#
#
#
#
# 		General
#
#
#
#  What links here Related changes Upload file Special pages Permanent link Page information Cite this page Get shortened URL Download QR code Wikidata item
#
#
#
#
#
# 		Print/export
#
#
#
#  Download as PDF Printable version
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  From Wikipedia, the free encyclopedia
#
#
#  Public image of Taylor Swift
#  For her overall public influence, see  Cultural impact of Taylor Swift .
# Sentence 2: She began dating American football player  Travis Kelce  in 2023, which has had a significant cultural impact, including a contribution of $331.5 million in  brand value  for the  National Football League  (NFL).
# Sentence 3: [121] [127]
#
#  Travis Kelce [ edit ]
#  American football player  Travis Kelce  in 2021
#  Swift began dating  American football  player  Travis Kelce  around August 2023.
#
# Term: Personal Information
#
# Term: Height
# Sentence 1: The public has shown a heightened interest in news about Swift, which has encouraged media outlets to hyperfocus on her.
# Sentence 2: At its height, western swing rivaled the popularity of  big band  swing music.
# Sentence 3: [194]  In May 1977, the Sex Pistols achieved new heights of controversy (and number two on the singles chart) with a song that referenced  Queen Elizabeth II , " God Save the Queen ", during her  Silver Jubilee .

# %%
# Load the knowledge base from the pickle file
with open('knowledge_base.pkl', 'rb') as f:
    knowledge_base = pickle.load(f)

# Print all keys
print("Keys in the knowledge base:")
for key in knowledge_base.keys():
    print(key)
# Out:
# Keys in the knowledge base:
# american
# video
# time
# 2024
# folk
# awards
# tour
# january
# edit
# nashville
# new
# 2017
# july
# 2015
# march
# album
# pop
# may
# april
# february
# august
# records
# billboard
# rock
# swifts
# december
# 2019
# 2022
# country
# 2020
# october
# november
# 2021
# 2023
# archived
# original
# music
# retrieved
# taylor
# swift
# Reputation
# Lover
# Red (album)
# Grammy Awards
# Country Music
# Pop Music
# Eras Tour
# Billboard charts
# 1989 (album)
# Taylor Swift Foundation
# Travis Kelce
# Personal Information
# Height
